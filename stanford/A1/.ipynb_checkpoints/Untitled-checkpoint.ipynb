# %%
import numpy as np

# %%
a = np.random.randint(5, size=(4,), dtype=int)
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-4c004c8e3a4b> in <module>()
# ----> 1 a = np.random.randint(5, shape=(4,), dtype=int)
#       2 print(a)
#
# mtrand.pyx in mtrand.RandomState.randint()
#
# TypeError: randint() got an unexpected keyword argument 'shape'
